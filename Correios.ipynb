# %%
import pandas as pd
import numpy as np

# %%
df_Agencias_Bancos= pd.read_csv("Dados/Agencias/Agencias.csv",sep=";",encoding="latin1")
df_Abrev_Enderecos= pd.read_csv("Dados/Agencias/Abreviaturas_Enderco.csv",sep=",",encoding="latin1")
Nome_Colunas=["CNPJ","SEQUENCIAL_DO_CNP","DV_DO_CNPJ","NOME_INSTITUICAO","SEGMENTO","COD_COMPE_AG","NOME_DA_AGENCIA","ENDERECO","NUMERO","COMPLEMENTO","BAIRRO","CEP","MUNICIPIO","UF","DATA_INICIO","DDD","FONE"]
df_Agencias_Bancos.columns=Nome_Colunas
print ("Quantidade de Bancos: "+ str(len(df_Agencias_Bancos)))
print ("Quantidade de Abreviacoes de Enderecos: "+ str(len(df_Abrev_Enderecos)))
df_Agencias_Bancos.head()
# Out:
# Quantidade de Bancos: 21603
# Quantidade de Abreviacoes de Enderecos: 7
#          CNPJ  SEQUENCIAL_DO_CNP  DV_DO_CNPJ      NOME_INSTITUICAO  \
# 0  00.000.000                2.0        72.0  BANCO DO BRASIL S.A.
# 1  00.000.000                3.0        53.0  BANCO DO BRASIL S.A.
# 2  00.000.000                4.0        34.0  BANCO DO BRASIL S.A.
# 3  00.000.000                5.0        15.0  BANCO DO BRASIL S.A.
# 4  00.000.000                6.0         4.0  BANCO DO BRASIL S.A.
#
#                            SEGMENTO  COD_COMPE_AG    NOME_DA_AGENCIA  \
# 0  Banco do Brasil - Banco Múltiplo           2.0             MANAUS
# 1  Banco do Brasil - Banco Múltiplo           3.0  PRESIDENTE VARGAS
# 2  Banco do Brasil - Banco Múltiplo           4.0             SANTOS
# 3  Banco do Brasil - Banco Múltiplo           5.0  CAMPOS GOYTACAZES
# 4  Banco do Brasil - Banco Múltiplo           6.0           SALVADOR
#
#                      ENDERECO NUMERO                    COMPLEMENTO   BAIRRO  \
# 0     R.GUILHERME MOREIRA,315    NaN         SUBLOJA,LOJA E 2.ANDAR   CENTRO
# 1          AV.PRES.VARGAS,248    NaN                  1.E 2.ANDARES  CAMPINA
# 2    R.QUINZE DE NOVEMBRO,195    NaN                            NaN   CENTRO
# 3  PCA.DAS QUATRO JORNADAS,11    NaN                       MEZANINO   CENTRO
# 4           SEXTA AVENIDA,600    NaN  SECRETARIA DA EDUCACAO-TERREO      CAB
#
#          CEP              MUNICIPIO  UF DATA_INICIO   DDD        FONE
# 0  69005-300                 MANAUS  AM  14/01/1908  92.0  36215500.0
# 1  66010-900                  BELEM  PA  01/07/1908  91.0  32164888.0
# 2  11010-908                 SANTOS  SP  22/08/1908  13.0  40097406.0
# 3  28010-000  CAMPOS DOS GOYTACAZES  RJ  26/06/1910  22.0  27370405.0
# 4  41745-002               SALVADOR  BA  15/07/1910  71.0  33628803.0

# %%
#Separando as primeiras letras da coluna do endereco
df_Agencias_Bancos["ENDERECO"]=df_Agencias_Bancos["ENDERECO"].str.lower()
df_Agencias_Bancos['Abrev_Endereco'] = df_Agencias_Bancos.ENDERECO.str.split(".").str.get(0)
df_Agencias_Bancos.head()
# Out:
#          CNPJ  SEQUENCIAL_DO_CNP  DV_DO_CNPJ      NOME_INSTITUICAO  \
# 0  00.000.000                2.0        72.0  BANCO DO BRASIL S.A.
# 1  00.000.000                3.0        53.0  BANCO DO BRASIL S.A.
# 2  00.000.000                4.0        34.0  BANCO DO BRASIL S.A.
# 3  00.000.000                5.0        15.0  BANCO DO BRASIL S.A.
# 4  00.000.000                6.0         4.0  BANCO DO BRASIL S.A.
#
#                            SEGMENTO  COD_COMPE_AG    NOME_DA_AGENCIA  \
# 0  Banco do Brasil - Banco Múltiplo           2.0             MANAUS
# 1  Banco do Brasil - Banco Múltiplo           3.0  PRESIDENTE VARGAS
# 2  Banco do Brasil - Banco Múltiplo           4.0             SANTOS
# 3  Banco do Brasil - Banco Múltiplo           5.0  CAMPOS GOYTACAZES
# 4  Banco do Brasil - Banco Múltiplo           6.0           SALVADOR
#
#                      ENDERECO NUMERO                    COMPLEMENTO   BAIRRO  \
# 0     r.guilherme moreira,315    NaN         SUBLOJA,LOJA E 2.ANDAR   CENTRO
# 1          av.pres.vargas,248    NaN                  1.E 2.ANDARES  CAMPINA
# 2    r.quinze de novembro,195    NaN                            NaN   CENTRO
# 3  pca.das quatro jornadas,11    NaN                       MEZANINO   CENTRO
# 4           sexta avenida,600    NaN  SECRETARIA DA EDUCACAO-TERREO      CAB
#
#          CEP              MUNICIPIO  UF DATA_INICIO   DDD        FONE  \
# 0  69005-300                 MANAUS  AM  14/01/1908  92.0  36215500.0
# 1  66010-900                  BELEM  PA  01/07/1908  91.0  32164888.0
# 2  11010-908                 SANTOS  SP  22/08/1908  13.0  40097406.0
# 3  28010-000  CAMPOS DOS GOYTACAZES  RJ  26/06/1910  22.0  27370405.0
# 4  41745-002               SALVADOR  BA  15/07/1910  71.0  33628803.0
#
#       Abrev_Endereco
# 0                  r
# 1                 av
# 2                  r
# 3                pca
# 4  sexta avenida,600

# %% [markdown]
# ### Primeira Correcao (Inferencia Correta)

# %%
df_Abrev_Enderecos["Abrev"]=df_Abrev_Enderecos["Abrev"].str.lower()
df_Abrev_Enderecos["Nome_Original"]=df_Abrev_Enderecos["Nome_Original"].str.lower()
df_Abrev_Enderecos.head()
# Out:
#   Abrev Nome_Original
# 0     r           rua
# 1    av       avenida
# 2   pca         praca
# 3     q        quadra
# 4    qd        quadra

# %%
#Convertendo to dictionary
#Dic_Abrev_Enderecos=df_Abrev_Enderecos.set_index('Abrev').T.to_dict('split')
Dic_Abrev_Enderecos=df_Abrev_Enderecos.set_index('Abrev')['Nome_Original'].to_dict()

# %%
df_Agencias_Bancos.head(20)
# Out:
#           CNPJ  SEQUENCIAL_DO_CNP  DV_DO_CNPJ      NOME_INSTITUICAO  \
# 0   00.000.000                2.0        72.0  BANCO DO BRASIL S.A.
# 1   00.000.000                3.0        53.0  BANCO DO BRASIL S.A.
# 2   00.000.000                4.0        34.0  BANCO DO BRASIL S.A.
# 3   00.000.000                5.0        15.0  BANCO DO BRASIL S.A.
# 4   00.000.000                6.0         4.0  BANCO DO BRASIL S.A.
# 5   00.000.000                7.0        87.0  BANCO DO BRASIL S.A.
# 6   00.000.000                8.0        68.0  BANCO DO BRASIL S.A.
# 7   00.000.000                9.0        49.0  BANCO DO BRASIL S.A.
# 8   00.000.000               10.0        82.0  BANCO DO BRASIL S.A.
# 9   00.000.000               11.0        63.0  BANCO DO BRASIL S.A.
# 10  00.000.000               12.0        44.0  BANCO DO BRASIL S.A.
# 11  00.000.000               13.0        25.0  BANCO DO BRASIL S.A.
# 12  00.000.000               14.0         6.0  BANCO DO BRASIL S.A.
# 13  00.000.000               15.0        97.0  BANCO DO BRASIL S.A.
# 14  00.000.000               16.0        78.0  BANCO DO BRASIL S.A.
# 15  00.000.000               18.0        30.0  BANCO DO BRASIL S.A.
# 16  00.000.000               19.0        10.0  BANCO DO BRASIL S.A.
# 17  00.000.000               20.0        54.0  BANCO DO BRASIL S.A.
# 18  00.000.000               21.0        35.0  BANCO DO BRASIL S.A.
# 19  00.000.000               22.0        16.0  BANCO DO BRASIL S.A.
#
#                             SEGMENTO  COD_COMPE_AG       NOME_DA_AGENCIA  \
# 0   Banco do Brasil - Banco Múltiplo           2.0                MANAUS
# 1   Banco do Brasil - Banco Múltiplo           3.0     PRESIDENTE VARGAS
# 2   Banco do Brasil - Banco Múltiplo           4.0                SANTOS
# 3   Banco do Brasil - Banco Múltiplo           5.0     CAMPOS GOYTACAZES
# 4   Banco do Brasil - Banco Múltiplo           6.0              SALVADOR
# 5   Banco do Brasil - Banco Múltiplo           7.0                RECIFE
# 6   Banco do Brasil - Banco Múltiplo           8.0   S.PUBLICO FORTALEZA
# 7   Banco do Brasil - Banco Múltiplo           9.0   PRACA TIRADENTES-PR
# 8   Banco do Brasil - Banco Múltiplo          10.0  EMPRESA PORTO ALEGRE
# 9   Banco do Brasil - Banco Múltiplo          11.0   EMPRESA JOAO PESSOA
# 10  Banco do Brasil - Banco Múltiplo          12.0         TRES CORACOES
# 11  Banco do Brasil - Banco Múltiplo          13.0                MACEIO
# 12  Banco do Brasil - Banco Múltiplo          14.0               CORUMBA
# 13  Banco do Brasil - Banco Múltiplo          15.0               UBERABA
# 14  Banco do Brasil - Banco Múltiplo          16.0         FLORIANOPOLIS
# 15  Banco do Brasil - Banco Múltiplo          18.0             SAO PAULO
# 16  Banco do Brasil - Banco Múltiplo          19.0                ILHEUS
# 17  Banco do Brasil - Banco Múltiplo          20.0              SAO LUIS
# 18  Banco do Brasil - Banco Múltiplo          21.0       EMPRESA VITORIA
# 19  Banco do Brasil - Banco Múltiplo          22.0         EMPRESA NATAL
#
#                           ENDERECO NUMERO                    COMPLEMENTO  \
# 0          r.guilherme moreira,315    NaN         SUBLOJA,LOJA E 2.ANDAR
# 1               av.pres.vargas,248    NaN                  1.E 2.ANDARES
# 2         r.quinze de novembro,195    NaN                            NaN
# 3       pca.das quatro jornadas,11    NaN                       MEZANINO
# 4                sexta avenida,600    NaN  SECRETARIA DA EDUCACAO-TERREO
# 5                av.rio branco,240    NaN                        1.ANDAR
# 6            av.santos dumont,2828    NaN                        5.ANDAR
# 7               pca.tiradentes,410    NaN                        1.ANDAR
# 8                    r.uruguai,185    NaN                        5.ANDAR
# 9                     pca.1817,129    NaN                        1.ANDAR
# 10   pca.odilon resende andrade,76    NaN                            NaN
# 11         av fernandes lima, 2591    NaN                         TERREO
# 12            r.treze de junho,914    NaN                            NaN
# 13  av.leopoldino de oliveira,3635    NaN                            NaN
# 14      pca.quinze de novembro,321    NaN                            NaN
# 15                 r.sao bento,483    NaN                            NaN
# 16      r.marques de paranagua,112    NaN                            NaN
# 17           av.gomes de castro,46    NaN                        2.ANDAR
# 18                 pca.pio doze,30    NaN                        2.ANDAR
# 19               av.rio branco,510    NaN                        2.ANDAR
#
#            BAIRRO        CEP              MUNICIPIO  UF DATA_INICIO   DDD  \
# 0          CENTRO  69005-300                 MANAUS  AM  14/01/1908  92.0
# 1         CAMPINA  66010-900                  BELEM  PA  01/07/1908  91.0
# 2          CENTRO  11010-908                 SANTOS  SP  22/08/1908  13.0
# 3          CENTRO  28010-000  CAMPOS DOS GOYTACAZES  RJ  26/06/1910  22.0
# 4             CAB  41745-002               SALVADOR  BA  15/07/1910  71.0
# 5   RECIFE ANTIGO  50030-310                 RECIFE  PE  12/08/1913  81.0
# 6         ALDEOTA  60150-162              FORTALEZA  CE  14/08/1913  85.0
# 7          CENTRO  80020-100               CURITIBA  PR  07/01/1916  41.0
# 8          CENTRO  90010-901           PORTO ALEGRE  RS  01/03/1916  51.0
# 9          CENTRO  58013-010            JOAO PESSOA  PB  01/04/1916  83.0
# 10         CENTRO  37410-000          TRES CORACOES  MG  05/07/1916  35.0
# 11          FAROL  57057-972                 MACEIO  AL  24/07/1916  82.0
# 12         CENTRO  79300-040                CORUMBA  MS  25/07/1916  67.0
# 13         CENTRO  38010-000                UBERABA  MG  10/08/1916  34.0
# 14         CENTRO  88010-400          FLORIANOPOLIS  SC  15/09/1916  48.0
# 15         CENTRO  01011-100              SAO PAULO  SP  02/01/1917  11.0
# 16         CENTRO  45653-000                 ILHEUS  BA  01/03/1917  73.0
# 17         CENTRO  65020-230               SAO LUIS  MA  01/04/1917  98.0
# 18         CENTRO  29010-340                VITORIA  ES  02/04/1917  27.0
# 19    CIDADE ALTA  59025-900                  NATAL  RN  14/04/1917  84.0
#
#           FONE           Abrev_Endereco
# 0   36215500.0                        r
# 1   32164888.0                       av
# 2   40097406.0                        r
# 3   27370405.0                      pca
# 4   33628803.0        sexta avenida,600
# 5   34257530.0                       av
# 6   33660800.0                       av
# 7   33212439.0                      pca
# 8   32147890.0                        r
# 9   40033001.0                      pca
# 10  32321155.0                      pca
# 11  31942750.0  av fernandes lima, 2591
# 12  32312686.0                        r
# 13  40033001.0                       av
# 14  32211600.0                      pca
# 15  34913992.0                        r
# 16  36342813.0                        r
# 17  32163410.0                       av
# 18  33312794.0                      pca
# 19  40033001.0                       av

# %%
#Funcao de Correcao ortografica de acordo ao dicionario
def f_Correcao_Abrev_to_Nome(df,Dic ,Coluna):
    cont=0
    for Valor_Abrev in df[Coluna]:
        if Dic.get(Valor_Abrev)!=None:
            df=df.set_value(cont,Coluna,Dic.get(Valor_Abrev))
        cont=cont+1
    return df

# %%
df_Corregido_com_Pontos= f_Correcao_Abrev_to_Nome(df_Agencias_Bancos,Dic_Abrev_Enderecos,"Abrev_Endereco")
df_Corregido_com_Pontos.head()
# Out:
# C:\Users\emily\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#          CNPJ  SEQUENCIAL_DO_CNP  DV_DO_CNPJ      NOME_INSTITUICAO  \
# 0  00.000.000                2.0        72.0  BANCO DO BRASIL S.A.
# 1  00.000.000                3.0        53.0  BANCO DO BRASIL S.A.
# 2  00.000.000                4.0        34.0  BANCO DO BRASIL S.A.
# 3  00.000.000                5.0        15.0  BANCO DO BRASIL S.A.
# 4  00.000.000                6.0         4.0  BANCO DO BRASIL S.A.
#
#                            SEGMENTO  COD_COMPE_AG    NOME_DA_AGENCIA  \
# 0  Banco do Brasil - Banco Múltiplo           2.0             MANAUS
# 1  Banco do Brasil - Banco Múltiplo           3.0  PRESIDENTE VARGAS
# 2  Banco do Brasil - Banco Múltiplo           4.0             SANTOS
# 3  Banco do Brasil - Banco Múltiplo           5.0  CAMPOS GOYTACAZES
# 4  Banco do Brasil - Banco Múltiplo           6.0           SALVADOR
#
#                      ENDERECO NUMERO                    COMPLEMENTO   BAIRRO  \
# 0     r.guilherme moreira,315    NaN         SUBLOJA,LOJA E 2.ANDAR   CENTRO
# 1          av.pres.vargas,248    NaN                  1.E 2.ANDARES  CAMPINA
# 2    r.quinze de novembro,195    NaN                            NaN   CENTRO
# 3  pca.das quatro jornadas,11    NaN                       MEZANINO   CENTRO
# 4           sexta avenida,600    NaN  SECRETARIA DA EDUCACAO-TERREO      CAB
#
#          CEP              MUNICIPIO  UF DATA_INICIO   DDD        FONE  \
# 0  69005-300                 MANAUS  AM  14/01/1908  92.0  36215500.0
# 1  66010-900                  BELEM  PA  01/07/1908  91.0  32164888.0
# 2  11010-908                 SANTOS  SP  22/08/1908  13.0  40097406.0
# 3  28010-000  CAMPOS DOS GOYTACAZES  RJ  26/06/1910  22.0  27370405.0
# 4  41745-002               SALVADOR  BA  15/07/1910  71.0  33628803.0
#
#       Abrev_Endereco
# 0                rua
# 1            avenida
# 2                rua
# 3              praca
# 4  sexta avenida,600

# %%
#Condicion que pega a primera letra que esta separado por espaco para ser remplazado na mesma columna
Condicao_Sem_Ponto=(df_Corregido_com_Pontos.Abrev_Endereco.str.split(" ").str.get(1).notnull())
df_Corregido_com_Pontos.loc[Condicao_Sem_Ponto, 'Abrev_Endereco']=df_Corregido_com_Pontos.Abrev_Endereco.str.split(" ").str.get(0)
df_Corregido_com_Pontos.head()
# Out:
#          CNPJ  SEQUENCIAL_DO_CNP  DV_DO_CNPJ      NOME_INSTITUICAO  \
# 0  00.000.000                2.0        72.0  BANCO DO BRASIL S.A.
# 1  00.000.000                3.0        53.0  BANCO DO BRASIL S.A.
# 2  00.000.000                4.0        34.0  BANCO DO BRASIL S.A.
# 3  00.000.000                5.0        15.0  BANCO DO BRASIL S.A.
# 4  00.000.000                6.0         4.0  BANCO DO BRASIL S.A.
#
#                            SEGMENTO  COD_COMPE_AG    NOME_DA_AGENCIA  \
# 0  Banco do Brasil - Banco Múltiplo           2.0             MANAUS
# 1  Banco do Brasil - Banco Múltiplo           3.0  PRESIDENTE VARGAS
# 2  Banco do Brasil - Banco Múltiplo           4.0             SANTOS
# 3  Banco do Brasil - Banco Múltiplo           5.0  CAMPOS GOYTACAZES
# 4  Banco do Brasil - Banco Múltiplo           6.0           SALVADOR
#
#                      ENDERECO NUMERO                    COMPLEMENTO   BAIRRO  \
# 0     r.guilherme moreira,315    NaN         SUBLOJA,LOJA E 2.ANDAR   CENTRO
# 1          av.pres.vargas,248    NaN                  1.E 2.ANDARES  CAMPINA
# 2    r.quinze de novembro,195    NaN                            NaN   CENTRO
# 3  pca.das quatro jornadas,11    NaN                       MEZANINO   CENTRO
# 4           sexta avenida,600    NaN  SECRETARIA DA EDUCACAO-TERREO      CAB
#
#          CEP              MUNICIPIO  UF DATA_INICIO   DDD        FONE  \
# 0  69005-300                 MANAUS  AM  14/01/1908  92.0  36215500.0
# 1  66010-900                  BELEM  PA  01/07/1908  91.0  32164888.0
# 2  11010-908                 SANTOS  SP  22/08/1908  13.0  40097406.0
# 3  28010-000  CAMPOS DOS GOYTACAZES  RJ  26/06/1910  22.0  27370405.0
# 4  41745-002               SALVADOR  BA  15/07/1910  71.0  33628803.0
#
#   Abrev_Endereco
# 0            rua
# 1        avenida
# 2            rua
# 3          praca
# 4          sexta

# %%
#Funcao para Criar uma flag dos Corregidos
def f_Coluna_Flag_to_Corregido(df,dic,Nome_Coluna_Compare,Nome_Coluna_Flag):
    #Criando uma flag para ver que abreviacoes foram arrumadas
    df[Nome_Coluna_Flag]=False
    contagem=0
    for Valor_Abrev in df[Nome_Coluna_Compare]:
        if (Valor_Abrev in dic.values())==True:
            df=df.set_value(contagem,Nome_Coluna_Flag,True)
        contagem=contagem+1
    return df, Nome_Coluna_Flag

# %%
df_Corregido_Ponto_Flag,Nome_Flag_Correc=f_Coluna_Flag_to_Corregido(df_Corregido_com_Pontos,Dic_Abrev_Enderecos,"Abrev_Endereco","Abrev_Ender_Flag_Correg")
print ("Nome da Coluna Flag Criada: "+Nome_Flag_Correc)
df_Corregido_Ponto_Flag.head()
# Out:
# Nome da Coluna Flag Criada: Abrev_Ender_Flag_Correg
# C:\Users\emily\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#          CNPJ  SEQUENCIAL_DO_CNP  DV_DO_CNPJ      NOME_INSTITUICAO  \
# 0  00.000.000                2.0        72.0  BANCO DO BRASIL S.A.
# 1  00.000.000                3.0        53.0  BANCO DO BRASIL S.A.
# 2  00.000.000                4.0        34.0  BANCO DO BRASIL S.A.
# 3  00.000.000                5.0        15.0  BANCO DO BRASIL S.A.
# 4  00.000.000                6.0         4.0  BANCO DO BRASIL S.A.
#
#                            SEGMENTO  COD_COMPE_AG    NOME_DA_AGENCIA  \
# 0  Banco do Brasil - Banco Múltiplo           2.0             MANAUS
# 1  Banco do Brasil - Banco Múltiplo           3.0  PRESIDENTE VARGAS
# 2  Banco do Brasil - Banco Múltiplo           4.0             SANTOS
# 3  Banco do Brasil - Banco Múltiplo           5.0  CAMPOS GOYTACAZES
# 4  Banco do Brasil - Banco Múltiplo           6.0           SALVADOR
#
#                      ENDERECO NUMERO                    COMPLEMENTO   BAIRRO  \
# 0     r.guilherme moreira,315    NaN         SUBLOJA,LOJA E 2.ANDAR   CENTRO
# 1          av.pres.vargas,248    NaN                  1.E 2.ANDARES  CAMPINA
# 2    r.quinze de novembro,195    NaN                            NaN   CENTRO
# 3  pca.das quatro jornadas,11    NaN                       MEZANINO   CENTRO
# 4           sexta avenida,600    NaN  SECRETARIA DA EDUCACAO-TERREO      CAB
#
#          CEP              MUNICIPIO  UF DATA_INICIO   DDD        FONE  \
# 0  69005-300                 MANAUS  AM  14/01/1908  92.0  36215500.0
# 1  66010-900                  BELEM  PA  01/07/1908  91.0  32164888.0
# 2  11010-908                 SANTOS  SP  22/08/1908  13.0  40097406.0
# 3  28010-000  CAMPOS DOS GOYTACAZES  RJ  26/06/1910  22.0  27370405.0
# 4  41745-002               SALVADOR  BA  15/07/1910  71.0  33628803.0
#
#   Abrev_Endereco  Abrev_Ender_Flag_Correg
# 0            rua                     True
# 1        avenida                     True
# 2            rua                     True
# 3          praca                     True
# 4          sexta                    False

# %%
#Agrupando aqueles que nao foram arrumados para o proximo Tratamento
df_Agencias_Bancos_Pra_Tratar=df_Corregido_Ponto_Flag[df_Corregido_Ponto_Flag[Nome_Flag_Correc]==False]
print ("O numero de registros para arrumar sao: "+str(len(df_Agencias_Bancos_Pra_Tratar)))
df_Agencias_Bancos_Pra_Tratar.head()
# Out:
# O numero de registros para arrumar sao: 3870
#            CNPJ  SEQUENCIAL_DO_CNP  DV_DO_CNPJ      NOME_INSTITUICAO  \
# 4    00.000.000                6.0         4.0  BANCO DO BRASIL S.A.
# 11   00.000.000               13.0        25.0  BANCO DO BRASIL S.A.
# 68   00.000.000               71.0         2.0  BANCO DO BRASIL S.A.
# 177  00.000.000              181.0        39.0  BANCO DO BRASIL S.A.
# 254  00.000.000              259.0        33.0  BANCO DO BRASIL S.A.
#
#                              SEGMENTO  COD_COMPE_AG     NOME_DA_AGENCIA  \
# 4    Banco do Brasil - Banco Múltiplo           6.0            SALVADOR
# 11   Banco do Brasil - Banco Múltiplo          13.0              MACEIO
# 68   Banco do Brasil - Banco Múltiplo          71.0  EMPRESA RIO BRANCO
# 177  Banco do Brasil - Banco Múltiplo         181.0     BENTO GONCALVES
# 254  Banco do Brasil - Banco Múltiplo         259.0           PARANAGUA
#
#                          ENDERECO NUMERO                    COMPLEMENTO  \
# 4               sexta avenida,600    NaN  SECRETARIA DA EDUCACAO-TERREO
# 11        av fernandes lima, 2591    NaN                         TERREO
# 68   r  arlindo porto leal no. 85    NaN                            NaN
# 177       r marechal floriano, 85    NaN                            NaN
# 254       lgo.conego alcindino,27    NaN                            NaN
#
#                BAIRRO        CEP        MUNICIPIO  UF DATA_INICIO   DDD  \
# 4                 CAB  41745-002         SALVADOR  BA  15/07/1910  71.0
# 11              FAROL  57057-972           MACEIO  AL  24/07/1916  82.0
# 68             CENTRO  69900-058       RIO BRANCO  AC  25/01/1928  68.0
# 177            CENTRO  95700-110  BENTO GONCALVES  RS  27/04/1942  54.0
# 254  CENTRO HISTORICO  83203-330        PARANAGUA  PR  20/12/1944  41.0
#
#            FONE Abrev_Endereco  Abrev_Ender_Flag_Correg
# 4    33628803.0          sexta                    False
# 11   31942750.0             av                    False
# 68   40033001.0              r                    False
# 177  34493800.0              r                    False
# 254  34201850.0            lgo                    False

# %%
df_Agencias_Bancos_Pra_Tratar.Abrev_Endereco.value_counts().iloc[:20]
# Out:
# av         1504
# r           653
# praça       262
# estrada     145
# alameda     125
# pca          84
# rodovia      83
# pc           82
# rod          78
#              70
# pça          45
# al           44
# est          33
# largo        29
# praia        24
# setor        19
# st           17
# estr         17
# tv           16
# lgo          12
# Name: Abrev_Endereco, dtype: int64

# %% [markdown]
# ### Segundo Tratamento (INFERENCIA)

# %%
df_Corregido_Sem_Pontos= f_Correcao_Abrev_to_Nome(df_Agencias_Bancos_Pra_Tratar,Dic_Abrev_Enderecos,"Abrev_Endereco")
df_Corregido_Sem_Pontos.head()
# Out:
# C:\Users\emily\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#            CNPJ  SEQUENCIAL_DO_CNP  DV_DO_CNPJ      NOME_INSTITUICAO  \
# 4    00.000.000                6.0         4.0  BANCO DO BRASIL S.A.
# 11   00.000.000               13.0        25.0  BANCO DO BRASIL S.A.
# 68   00.000.000               71.0         2.0  BANCO DO BRASIL S.A.
# 177  00.000.000              181.0        39.0  BANCO DO BRASIL S.A.
# 254  00.000.000              259.0        33.0  BANCO DO BRASIL S.A.
#
#                              SEGMENTO  COD_COMPE_AG     NOME_DA_AGENCIA  \
# 4    Banco do Brasil - Banco Múltiplo           6.0            SALVADOR
# 11   Banco do Brasil - Banco Múltiplo          13.0              MACEIO
# 68   Banco do Brasil - Banco Múltiplo          71.0  EMPRESA RIO BRANCO
# 177  Banco do Brasil - Banco Múltiplo         181.0     BENTO GONCALVES
# 254  Banco do Brasil - Banco Múltiplo         259.0           PARANAGUA
#
#                          ENDERECO NUMERO                    COMPLEMENTO  \
# 4               sexta avenida,600    NaN  SECRETARIA DA EDUCACAO-TERREO
# 11        av fernandes lima, 2591    NaN                         TERREO
# 68   r  arlindo porto leal no. 85    NaN                            NaN
# 177       r marechal floriano, 85    NaN                            NaN
# 254       lgo.conego alcindino,27    NaN                            NaN
#
#                BAIRRO        CEP        MUNICIPIO  UF DATA_INICIO   DDD  \
# 4                 CAB  41745-002         SALVADOR  BA  15/07/1910  71.0
# 11              FAROL  57057-972           MACEIO  AL  24/07/1916  82.0
# 68             CENTRO  69900-058       RIO BRANCO  AC  25/01/1928  68.0
# 177            CENTRO  95700-110  BENTO GONCALVES  RS  27/04/1942  54.0
# 254  CENTRO HISTORICO  83203-330        PARANAGUA  PR  20/12/1944  41.0
#
#            FONE Abrev_Endereco Abrev_Ender_Flag_Correg
# 4    33628803.0          sexta                   False
# 11   31942750.0             av                   False
# 68   40033001.0        avenida                   False
# 177  34493800.0              r                   False
# 254  34201850.0        avenida                   False

# %%
import nltk
def ie_preprocess(document):
    sentences = nltk.sent_tokenize(document)
    print (sentences)
    sentences = [nltk.word_tokenize(sent) for sent in sentences]
    print (sentences)
    sentences = [nltk.pos_tag(sent) for sent in sentences]
    print (sentences)

ie_preprocess(df_Agencias_Bancos.ENDERECO[1])

# %%
nltk.download('averaged_perceptron_tagger')

# %%
len(df_Agencias_Bancos[df_Agencias_Bancos.MUNICIPIO=='SAO PAULO'].CEP.unique())

# %%
df_Agencias_Bancos.MUNICIPIO.unique()[15]

# %%
df_Agencias_Bancos.ENDERECO[1]

# %%
NOME="AV.  PRES. VARGAS, 248"
ie_preprocess(NOME)

# %%
NOME_2="PCA. DAS QUATRO JORNADAS em JOA CARLOS GUTERRES, 11"
ie_preprocess(NOME_2)

# %%
NOME_2="PCA. DAS QUATRO JORNADAS em JR. JOA CARLOS GUTERRES, AV. PAULO SANTOS 11"
ie_preprocess(NOME_2)
